# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Mall_Customers.csv')
data.head(5)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.shape
# Out:
# (200, 5)

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
import missingno as msno

# %%
msno.matrix(data)

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %% [markdown]
# DATA VISUALIZATION :

# %%
plt.figure(figsize=(16, 5))
plt.subplot(1, 3, 1)
sns.distplot(data['Age'])
plt.title('Distribution of Age')
plt.xlabel('Range of Age')
plt.ylabel('count')

plt.subplot(1, 3, 2)
sns.distplot(data['Annual Income (k$)'])
plt.title('Distrimution of Income')
plt.xlabel('Range of Income')
plt.ylabel('count')

plt.subplot(1, 3, 3)
sns.distplot(data['Spending Score (1-100)'])
plt.title('Distribution of Spending Score')
plt.xlabel('Range of Spending Score')
plt.ylabel('count')
plt.show()
# Out:
# /tmp/ipykernel_7598/82415632.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'])
# /tmp/ipykernel_7598/82415632.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual Income (k$)'])
# /tmp/ipykernel_7598/82415632.py:15: UserWarning:
#
# ...

# %%
df = data.groupby('Gender').size()

df.plot(kind='pie', 
    colors=['lightgreen', 'orange'],
    explode=[0, 0.001],
    labels=['Female', 'Male'],
    autopct='%.2f%%')
plt.title('Gender Distribution')
plt.ylabel('Gender')
plt.show()

# %%
data.hist(figsize = (12, 7))
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
sns.pairplot(data, vars = ['Spending Score (1-100)', 'Annual Income (k$)', 'Age'], hue = 'Gender')

# %%
plt.figure(figsize=(16, 8))
colors = sns.color_palette("Spectral", len(data['Age'].unique()))
sorted_ages = sorted(data['Age'].unique())
sns.countplot(x='Age', data=data, palette=colors, order=sorted_ages)
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_7598/3494399760.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Age', data=data, palette=colors, order=sorted_ages)

# %%
plt.figure(figsize=(16, 8))
sns.countplot(x='Annual Income (k$)', data=data, palette=colors)
plt.title("Distribution of Annual Income")
plt.xlabel("Annual Income (k$)")
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_7598/329505581.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Annual Income (k$)', data=data, palette=colors)
# /tmp/ipykernel_7598/329505581.py:2: UserWarning:
# The palette list has fewer values (51) than needed (64) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x='Annual Income (k$)', data=data, palette=colors)

# %%
plt.figure(figsize=(16, 8))
sns.countplot(x='Spending Score (1-100)', data=data, palette=colors)
plt.title("Distribution of Spending Score")
plt.xlabel("Spending Score (1-100)")
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_7598/1670701285.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Spending Score (1-100)', data=data, palette=colors)
# /tmp/ipykernel_7598/1670701285.py:2: UserWarning:
# The palette list has fewer values (51) than needed (84) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x='Spending Score (1-100)', data=data, palette=colors)

# %%
import dabl
dabl.plot(data, target_col = 'Spending Score (1-100)')

# %%
dabl.plot(data, target_col = 'Anuall Income (k$)')

# %%
sns.heatmap(data.corr(numeric_only=True), cmap='Wistia', annot=True)
plt.show()

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
plt.figure(figsize=(16, 8))
for gender in ['Male', 'Female']:
    subset = data[data['Gender'] == gender]
    plt.scatter(
        x=subset['Age'], 
        y=subset['Annual Income (k$)'], 
        s=200, alpha=0.5, label=gender
    )

plt.xlabel('Age')
plt.ylabel('Annual Income (k$)')
plt.title('Age vs Annual Income')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 8))
for gender in ['Male', 'Female']:
    subset = data[data['Gender'] == gender]
    plt.scatter(
        x=subset['Annual Income (k$)'], 
        y=subset['Spending Score (1-100)'], 
        s=200, alpha=0.5, label=gender
    )

plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.title('Annual Income vs Spending Score')
plt.legend()
plt.show()

# %% [markdown]
# K-MEANS CLUSTERING :

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
x= data.iloc[:,[3, 4]].values

# %%
x
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import KMeans

# %%
k = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(x)
    k.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),k)
plt.show()

# %%
model = KMeans(n_clusters=5, init='k-means++', max_iter=300, n_init=10, random_state=0)
y_kmeans = model.fit_predict(x)

# %%
plt.figure(1, figsize=(16, 8))
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s=100, c='red', label='Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s=100, c='blue', label='Cluster 2')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s=100, c='green', label='Cluster 3')
plt.scatter(x[y_kmeans == 3, 0], x[y_kmeans == 3, 1], s=100, c='cyan', label='Cluster 4')
plt.scatter(x[y_kmeans == 4, 0], x[y_kmeans == 4, 1], s=100, c='magenta', label='Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='yellow', label='Centroids')
plt.title('k Means Clustering Algorithm')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
